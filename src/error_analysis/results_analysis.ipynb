# %%
# %matplotlib inline

import os
import numpy as np
import matplotlib.pyplot as plt

from matplotlib.ticker import NullFormatter  # useful for `logit` scale

def read_data(method):
    num_iterations = 50
    model_dir = '/home/yhz/miniconda3/PAAR-main/model'
    model_paths = {
        'point.rs.conve': (
            'FB15K-237-10-point.rs.conve-xavier-n/a-200-200-3-0.001-0.3-0.1-0.0-400-0.02-True-True-False-20-2.0-1/',
            'FB15K-237-10-point.rs.conve-xavier-n/a-200-200-3-0.001-0.3-0.1-0.1-400-0.02-True-True-False-20-2.0-1/',
            'FB15K-237-10-point.rs.conve-xavier-n/a-200-200-3-0.001-0.3-0.1-0.3-400-0.02-True-True-False-20-2.0-1/',
            'FB15K-237-10-point.rs.conve-xavier-n/a-200-200-3-0.001-0.3-0.1-0.5-400-0.02-True-True-False-20-2.0-1/'
        )
    }
    
    # y1
    data1 = pd.read_csv(os.path.join(model_dir, model_paths[method][0], 'dev_metrics_list.dat'), header=None, names=['hit1', 'hit3', 'hit5', 'hit10', 'mrr'])
    print(model_paths[method][1])
    # y2
    data2 = pd.read_csv(os.path.join(model_dir, model_paths[method][1], 'dev_metrics_list.dat'), header=None, names=['hit1', 'hit3', 'hit5', 'hit10', 'mrr'])

    data3 = pd.read_csv(os.path.join(model_dir, model_paths[method][2], 'dev_metrics_list.dat'), header=None, names=['hit1', 'hit3', 'hit5', 'hit10', 'mrr'])

    data4 = pd.read_csv(os.path.join(model_dir, model_paths[method][3], 'dev_metrics_list.dat'), header=None, names=['hit1', 'hit3', 'hit5', 'hit10', 'mrr'])

        
    return data1, data2, data3, data4

# plot with various axes scales
#plt.figure(figsize=(12, 6))


#plt.subplot(222)
y1, y2, y3, y4 = read_data('point.rs.conve')
for column in y1.columns:
    x = np.arange(len(y1))
    plt.plot(y1[column], label=column)
    plt.plot(y2[column], label=column)
    plt.plot(y3[column], label=column)
    plt.plot(y4[column], label=column)
    plt.title('PG+ConvE')
    #plt.xlabel('Epoch')
    plt.ylabel(column)
    plt.legend((r'$\alpha=0.0$', r'$\alpha=0.1$', r'$\alpha=0.3$', r'$\alpha=0.5$'), loc='lower right')
    plt.grid(True) 
    plt.show()

# Format the minor tick labels of the y-axis into empty strings with
# `NullFormatter`, to avoid cumbering the axis with too many labels.
#plt.gca().yaxis.set_minor_formatter(NullFormatter())
# Adjust the subplot layout, because the logit one may take more space
# than usual, due to y-tick labels like "1 - 10^{-3}"
#plt.subplots_adjust(top=0.92, bottom=0.08, left=0.10, right=0.95, hspace=0.25,
#                    wspace=0.35)

plt.show()
# Out:
# FB15K-237-10-point.rs.conve-xavier-n/a-200-200-3-0.001-0.3-0.1-0.1-400-0.02-True-True-False-20-2.0-1/

# %%
y1.columns
# Out:
# Index(['hit1', 'hit3', 'hit5', 'hit10', 'mrr'], dtype='object')

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the data from CSV
data = pd.read_csv('/home/yhz/miniconda3/PAAR-main/model/FB15K-237-10-point.rs.conve-xavier-n/a-200-200-3-0.001-0.3-0.1-0.3-400-0.02-True-True-False-20-2.0-1/dev_metrics_list.dat', header=None, names=['hit1', 'hit3', 'hit5', 'hit10', 'mrr'])

# Plot each metric
plt.figure(figsize=(10, 6))  # Set the figure size
for column in data.columns:
    plt.plot(data[column], label=column)

# Add some plot decorations
plt.title('Development Set Performance Over Epochs')
plt.xlabel('Epoch')
plt.ylabel('Metric Values')
plt.legend()  # Show legend to identify the lines
plt.grid(True)  # Add grid for better readability

# Show the plot
plt.show()

# %%
# Out:
# '0.05547850208044383,0.10679611650485436,0.13638465094775776,0.18030513176144244,0.09473656199780181\n0.04854368932038835,0.12991215903837264,0.16920943134535368,0.21914008321775313,0.10755469643833748\n0.0425335182616736,0.11881645862228386,0.17891816920943135,0.23439667128987518,0.10644006095844977\n0.10078594544613963,0.19186315302820156,0.24040684234858992,0.3282478039759593,0.17482509992127673\n0.11881645862228386,0.3005085529357374,0.37078132223763294,0.44845122515025426,0.2366927021321572\n0.077207582061951,0.36754507628294036,0.44937586685159503,0.5270457697642164,0.2442421151028478\n0.06287563569116968,0.36523347202958856,0.46740638002773927,0.5547850208044383,0.24145694690857636\n0.0545538603791031,0.34766527970411465,0.454461396208969,0.5529357374017568,0.23234878276246432\n'

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the data from CSV
data = pd.read_csv('/home/yhz/miniconda3/PAAR-main/model/FB15K-237-10-point.rs.conve-xavier-n/a-200-200-3-0.001-0.3-0.1-0.5-400-0.02-True-True-False-20-2.0-1/training_loss_entropy_extracted.csv')

# Plotting
plt.figure(figsize=(10, 5))

# Line plot for Training Loss
plt.plot(data['Epoch'], data['Training Loss'], label='Training Loss', color='blue')

# Line plot for Entropy
plt.plot(data['Epoch'], data['Entropy'], label='Entropy', color='red')

plt.title('Training Loss and Entropy Over Epochs')
plt.xlabel('Epoch')
plt.ylabel('Value')
plt.legend()
plt.grid(True)
plt.show()
